# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv(r'C:\7 30pm batch FSDS&AI\2.August\17th - Test, Seaborn, Eda Practicle\EDA- HEALTHCARE DOMAIN\heart.csv')

# %%
df.shape
# Out:
# (303, 14)

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# # Dataset description
# The dataset contains several columns which are as follows
#
# -
# age : age in a
# -r-s
# sex : (1 = male; 0 = fma-l-e)
# cp : chest pin -t-ype
# trestbps : resting blood pressure (in mm Hg on admission to the hosp-i-tal)
# chol : serum cholestoral in- -mg/dl
# fbs : (fasting blood sugar > 120 mg/dl) (1 = true; 0 =- -false)
# restecg : resting electrocardiographic- -results
# thalach : maximum heart rate- -achieved
# exang : exercise induced angina (1 = ye-s-; 0 = no)
# oldpeak : ST depression induced by exercise relat-i-ve to rest
# slope : the slope of the peak exercis-e- ST segment
# ca : number of major vessels (0-3) colored -b-y flourosopy
# thal : 3 = normal; 6 = fixed defect; 7 = rev-e-rsable defect
# target : 1 or 0

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
df.describe(include='all')
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
#our feature variable is target so we can anlyze on this 
df['target'].nunique()
# Out:
# 2

# %%
df['target'].unique()
# Out:
# array([1, 0], dtype=int64)

# %% [markdown]
# # Comment
# On the above we can see two unique value of target are  1 (Present of heart disease)  and   0 (Absent of heart disease)

# %%
#Frequency distribution of target values
df['target'].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %% [markdown]
# # Comment
# So we can see that there are 165 patients suffering from heart disease and 138 patients are not suffering from heart disease

# %%
#Visualize this using graph
f, ax = plt.subplots(figsize=(6, 6))
ax = sns.countplot(x="target", data=df,palette='Set1')
plt.show()
# Out:
# C:\Users\Admin.DESKTOP-NUPAOG1\AppData\Local\Temp\ipykernel_2168\1315487790.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x="target", data=df,palette='Set1')

# %%
df['target'].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %% [markdown]
# # Comment
# here we can see that:
#
# -165 patients are suffering from heart disease
#
# -138 patients are not suffered from heart disease

# %%
co=df['sex'].value_counts()
co
# Out:
# sex
# 1    207
# 0     96
# Name: count, dtype: int64

# %%
df.groupby('sex')['target'].value_counts()
# Out:
# sex  target
# 0    1          72
#      0          24
# 1    0         114
#      1          93
# Name: count, dtype: int64

# %% [markdown]
# # Comment
# Now we can group two cloumn and here we see the data of target wrt to sex
#
# -In sex 0(female) and 1(male)
#
# -now we can say that out of 96 female 72 are suffering from heart disease and 24 are not
#
# -And out of 207 male 93 are suffering from heart disease and 114 are not

# %%
#Visualize target value wrt sex 
f, ax = plt.subplots(figsize=(6, 6))
ax = sns.countplot(x="sex",hue='target', data=df)
plt.show()

# %%
df.groupby('target')['sex'].value_counts()
# Out:
# target  sex
# 0       1      114
#         0       24
# 1       1       93
#         0       72
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize=(6, 6))
ax = sns.countplot(x="target", data=df, hue='sex')
plt.show()

# %%
ax = sns.catplot(x="target", col="sex", data=df, kind="count", height=5, aspect=1,hue='target')

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(y="target", data=df, hue='sex')
plt.show()

# %%
ax = sns.countplot(x="target", data=df, hue='sex',palette='Set3')

# %%
f, ax = plt.subplots(figsize=(6, 6))
ax = sns.countplot(x="target", data=df, facecolor=(0, 0, 0, 0), linewidth=5, edgecolor=sns.color_palette("dark", 3))
plt.show()

# %%
ax=sns.countplot(x='target',data=df,hue='fbs')

# %%
ax=sns.countplot(x='fbs',data=df,hue='target')

# %%
ax=sns.countplot(x='target',data=df,hue='exang')

# %%
correlation=df.corr()
correlation
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# target   -0.225439 -0.280937  0.433798 -0.144931 -0.085239 -0.028046
#
#            restecg   thalach     exang   oldpeak     slope        ca  \
# age      -0.116211 -0.398522  0.096801  0.210013 -0.168814  0.276326
# sex      -0.058196 -0.044020  0.141664  0.096093 -0.030711  0.118261
# cp        0.044421  0.295762 -0.394280 -0.149230  0.119717 -0.181053
# trestbps -0.114103 -0.046698  0.067616  0.193216 -0.121475  0.101389
# chol     -0.151040 -0.009940  0.067023  0.053952 -0.004038  0.070511
# fbs      -0.084189 -0.008567  0.025665  0.005747 -0.059894  0.137979
# restecg   1.000000  0.044123 -0.070733 -0.058770  0.093045 -0.072042
# thalach   0.044123  1.000000 -0.378812 -0.344187  0.386784 -0.213177
# exang    -0.070733 -0.378812  1.000000  0.288223 -0.257748  0.115739
# oldpeak  -0.058770 -0.344187  0.288223  1.000000 -0.577537  0.222682
# slope     0.093045  0.386784 -0.257748 -0.577537  1.000000 -0.080155
# ca       -0.072042 -0.213177  0.115739  0.222682 -0.080155  1.000000
# thal     -0.011981 -0.096439  0.206754  0.210244 -0.104764  0.151832
# target    0.137230  0.421741 -0.436757 -0.430696  0.345877 -0.391724
#
#               thal    target
# age       0.068001 -0.225439
# sex       0.210041 -0.280937
# cp       -0.161736  0.433798
# trestbps  0.062210 -0.144931
# chol      0.098803 -0.085239
# fbs      -0.032019 -0.028046
# restecg  -0.011981  0.137230
# thalach  -0.096439  0.421741
# exang     0.206754 -0.436757
# oldpeak   0.210244 -0.430696
# slope    -0.104764  0.345877
# ca        0.151832 -0.391724
# thal      1.000000 -0.344029
# target   -0.344029  1.000000

# %%
correlation['target'][::-1] #or .sort_values(ascending=False)
# Out:
# target      1.000000
# thal       -0.344029
# ca         -0.391724
# slope       0.345877
# oldpeak    -0.430696
# exang      -0.436757
# thalach     0.421741
# restecg     0.137230
# fbs        -0.028046
# chol       -0.085239
# trestbps   -0.144931
# cp          0.433798
# sex        -0.280937
# age        -0.225439
# Name: target, dtype: float64

# %% [markdown]
# #### Interpretation of correlation coefficient
#
# - The correlation coefficient ranges from -1 to +1.
#
# - When it is close to +1, this signifies that there is a strong positive correlation. So, we can see that there is no variable which has strong positive correlation with `target` variable.
#
# - When it is clsoe to -1, it means that there is a strong negative correlation. So, we can see that there is no variable which has strong negative correlation with `target` variable.
#
# - When it is close to 0, it means that there is no correlation. So, there is no correlation between `target` and `fbs`.
#
# - We can see that the `cp` and `thalach` variables are mildly positively correlated with `target` variable. So, I will analyze the interaction between these features and `target` variable.

# %% [markdown]
# ### Analysis of `target` and `cp` variable

# %% [markdown]
# #### Explore `cp` variable
#
#
# - `cp` stands for chest pain type.
#
# - First, I will check number of unique values in `cp` variable.

# %%
df['cp'].nunique()
# Out:
# 4

# %%
df['cp'].unique()
# Out:
# array([3, 2, 1, 0], dtype=int64)

# %%
df['cp'].value_counts()
# Out:
# cp
# 0    143
# 2     87
# 1     50
# 3     23
# Name: count, dtype: int64

# %%
ax=sns.countplot(x='cp',data=df,palette='Set1')
# Out:
# C:\Users\Admin.DESKTOP-NUPAOG1\AppData\Local\Temp\ipykernel_2168\594441397.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x='cp',data=df,palette='Set1')

# %%
df.groupby('cp')['target'].value_counts()
# Out:
# cp  target
# 0   0         104
#     1          39
# 1   1          41
#     0           9
# 2   1          69
#     0          18
# 3   1          16
#     0           7
# Name: count, dtype: int64

# %%
ax=sns.countplot(x='cp',hue='target',data=df)

# %%
ax=sns.catplot(x='target',col='cp',data=df,kind='count',palette='Set1')
# Out:
# C:\Users\Admin.DESKTOP-NUPAOG1\AppData\Local\Temp\ipykernel_2168\3033147441.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.catplot(x='target',col='cp',data=df,kind='count',palette='Set1')

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df['thalach'].nunique()
# Out:
# 91

# %%
df['thalach'].value_counts()[:10]
# Out:
# thalach
# 162    11
# 160     9
# 163     9
# 152     8
# 173     8
# 125     7
# 144     7
# 143     7
# 150     7
# 132     7
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize=(40, 6))
ax=sns.countplot(x='thalach',data=df,palette='Set1')
# Out:
# C:\Users\Admin.DESKTOP-NUPAOG1\AppData\Local\Temp\ipykernel_2168\1385098191.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x='thalach',data=df,palette='Set1')

# %%
f, ax = plt.subplots(figsize=(10,6))
x = df['thalach']
ax = sns.distplot(x, bins=10)
plt.show()
# Out:
# C:\Users\Admin.DESKTOP-NUPAOG1\AppData\Local\Temp\ipykernel_2168\3767373882.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(x, bins=10)

# %%
f, ax = plt.subplots(figsize=(10,6))
x = df['thalach']
x=pd.Series(x,name='Thalach varriable')
ax = sns.distplot(x, bins=10)
plt.show()
# Out:
# C:\Users\Admin.DESKTOP-NUPAOG1\AppData\Local\Temp\ipykernel_2168\3528111915.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(x, bins=10)

# %%
f, ax = plt.subplots(figsize=(10,6))
x = df['thalach']
ax = sns.distplot(x, bins=10,vertical=True)
plt.show()
# Out:
# C:\Users\Admin.DESKTOP-NUPAOG1\AppData\Local\Temp\ipykernel_2168\3141560756.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(x, bins=10,vertical=True)

# %%
#f, ax = plt.subplots(figsize=(10,6))
ax = sns.displot(data=df,x='thalach', bins=10)

# %%
#f, ax = plt.subplots(figsize=(10,6))
ax = sns.histplot(data=df,x='thalach', bins=10)

# %% [markdown]
# #### Seaborn Kernel Density Estimation (KDE) Plot
#
#
# - The kernel density estimate (KDE) plot is a useful tool for plotting the shape of a distribution.
#
# - The KDE plot plots the density of observations on one axis with height along the other axis.
#
# - We can plot a KDE plot as follows :

# %%
f, ax = plt.subplots(figsize=(10,6))
x = df['thalach']
x = pd.Series(x, name="thalach variable")
ax = sns.kdeplot(x)
plt.show()

# %%
f, ax = plt.subplots(figsize=(10,6))
x = df['thalach']
x = pd.Series(x, name="thalach variable")
ax = sns.kdeplot(x,shade=True,color='r')
plt.show()
# Out:
# C:\Users\Admin.DESKTOP-NUPAOG1\AppData\Local\Temp\ipykernel_2168\722435093.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(x,shade=True,color='r')

# %%
f, ax = plt.subplots(figsize=(10,6))
x = df['thalach']
ax = sns.distplot(x,kde=False,rug=True,bins=10)
plt.show()
# Out:
# C:\Users\Admin.DESKTOP-NUPAOG1\AppData\Local\Temp\ipykernel_2168\2139414974.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(x,kde=False,rug=True,bins=10)

# %%
f, ax = plt.subplots(figsize=(10,6))
x = df['thalach']
ax = sns.distplot(x,kde=False,rug=False,bins=10)
plt.show()
# Out:
# C:\Users\Admin.DESKTOP-NUPAOG1\AppData\Local\Temp\ipykernel_2168\4013708636.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(x,kde=False,rug=False,bins=10)

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.stripplot(x="target", y="thalach", data=df,palette='Set1')
plt.grid(axis='y')
plt.show()
# Out:
# C:\Users\Admin.DESKTOP-NUPAOG1\AppData\Local\Temp\ipykernel_2168\1647952026.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x="target", y="thalach", data=df,palette='Set1')

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.stripplot(x="target", y="thalach", data=df,jitter=0.01,palette='Set1')
plt.grid(axis='y')
plt.show()
# Out:
# C:\Users\Admin.DESKTOP-NUPAOG1\AppData\Local\Temp\ipykernel_2168\203229900.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x="target", y="thalach", data=df,jitter=0.01,palette='Set1')

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x="target", y="thalach", data=df,palette='Set1')
plt.grid(axis='y')
plt.show()
# Out:
# C:\Users\Admin.DESKTOP-NUPAOG1\AppData\Local\Temp\ipykernel_2168\351853407.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="target", y="thalach", data=df,palette='Set1')

# %% [markdown]
# # Comment
#
# The above boxplot confirms our finding that people suffering from heart disease (target = 1) have relatively higher heart rate (thalach) as compared to people who are not suffering from heart disease (target = 0).

# %% [markdown]
# # Multivariate Analysis

# %% [markdown]
# # Discover patterns and relationships
# An important step in EDA is to discover patterns and relationships between variables in the dataset.
#
# I will use heat map and pair plot to discover the patterns and relationships in the dataset.
#
# First of all, I will draw a heat map.

# %%
plt.figure(figsize=(16,12))
plt.title('correlation Heatmap of Heart Disease Dataset')
a = sns.heatmap(correlation, square=True, annot=True, fmt='.2f', linecolor='white')
a.set_xticklabels(a.get_xticklabels(), rotation=90)
a.set_yticklabels(a.get_yticklabels(), rotation=30)           
plt.show()

# %%
#Pair Plot
num_var = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'target' ]
sns.pairplot(df[num_var], kind='scatter', diag_kind='hist')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df['age'].nunique()
# Out:
# 41

# %%
df['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
f, ax = plt.subplots(figsize=(10,6))
x = df['age']
ax = sns.distplot(x, bins=10)
plt.show()
# Out:
# C:\Users\Admin.DESKTOP-NUPAOG1\AppData\Local\Temp\ipykernel_2168\1419425612.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(x, bins=10)

# %%
f, ax=plt.subplots(figsize=(8,6))
sns.stripplot(x='target',y='age',data=df,palette='Set1')
plt.grid(axis='y')
plt.show()
# Out:
# C:\Users\Admin.DESKTOP-NUPAOG1\AppData\Local\Temp\ipykernel_2168\21004476.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x='target',y='age',data=df,palette='Set1')

# %%
f, ax=plt.subplots(figsize=(8,6))
sns.stripplot(x='target',y='age',data=df,palette='Set1',jitter=0.01)
plt.grid(axis='y')
plt.show()
# Out:
# C:\Users\Admin.DESKTOP-NUPAOG1\AppData\Local\Temp\ipykernel_2168\908906097.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x='target',y='age',data=df,palette='Set1',jitter=0.01)

# %%
f, ax=plt.subplots(figsize=(8,6))
sns.boxplot(x='target',y='age',data=df,palette='Set1')
plt.grid(axis='y')
plt.show()
# Out:
# C:\Users\Admin.DESKTOP-NUPAOG1\AppData\Local\Temp\ipykernel_2168\2646471920.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='target',y='age',data=df,palette='Set1')

# %% [markdown]
# #### Interpretation
#
# - The above boxplot tells two different things :
#
#   - The mean age of the people who have heart disease is less than the mean age of the people who do not have heart disease.
#
#   - The dispersion or spread of age of the people who have heart disease is greater than the dispersion or spread of age of the people who do not have heart disease.

# %% [markdown]
# # Analyze `age` and `trestbps` varriable
#
# -I will plot a scatterplot to visualize the relationship between `age` and `trestbps` variable.

# %%
df['trestbps'].describe()
# Out:
# count    303.000000
# mean     131.623762
# std       17.538143
# min       94.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: trestbps, dtype: float64

# %%
f, ax=plt.subplots(figsize=(8,6))
ax=sns.scatterplot(x='age',y='trestbps',data=df)
plt.grid()
plt.show()

# %%
f, ax=plt.subplots(figsize=(8,6))
ax=sns.regplot(x='age',y='trestbps',data=df)
plt.grid()
plt.show()

# %% [markdown]
# #### Interpretation
#
# - The above line shows that linear regression model is not good fit to the data.

# %% [markdown]
# # Analyze `age` and `chol` variable

# %%
f, ax=plt.subplots(figsize=(8,6))
ax=sns.scatterplot(x='age',y='chol',data=df)
plt.grid()
plt.show()

# %%
f, ax=plt.subplots(figsize=(8,6))
ax=sns.regplot(x='age',y='chol',data=df)
plt.grid()
plt.show()

# %% [markdown]
# #### Interpretation
#
# - The above plot confirms that there is a slighly positive correlation between `age` and `chol` variables.

# %% [markdown]
# ### Analyze `chol` and `thalach` variable

# %%
f, ax=plt.subplots(figsize=(8,6))
ax=sns.scatterplot(x='chol',y='thalach',data=df)
plt.grid()
plt.show()

# %%
f, ax=plt.subplots(figsize=(8,6))
ax=sns.regplot(x='chol',y='thalach',data=df)
plt.grid()
plt.show()

# %% [markdown]
# #### Interpretation
#
#
# - The above plot shows that there is no correlation between `chol` and `thalach` variable.

# %% [markdown]
# # Check Missing Values

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# # Interpretation
#
# -there is no missing data in the dataset

# %%
 pd.notnull(df)
# Out:
#       age   sex    cp  trestbps  chol   fbs  restecg  thalach  exang  oldpeak  \
# 0    True  True  True      True  True  True     True     True   True     True
# 1    True  True  True      True  True  True     True     True   True     True
# 2    True  True  True      True  True  True     True     True   True     True
# 3    True  True  True      True  True  True     True     True   True     True
# 4    True  True  True      True  True  True     True     True   True     True
# ..    ...   ...   ...       ...   ...   ...      ...      ...    ...      ...
# 298  True  True  True      True  True  True     True     True   True     True
# 299  True  True  True      True  True  True     True     True   True     True
# 300  True  True  True      True  True  True     True     True   True     True
# 301  True  True  True      True  True  True     True     True   True     True
# 302  True  True  True      True  True  True     True     True   True     True
#
#      slope    ca  thal  target
# 0     True  True  True    True
# 1     True  True  True    True
# 2     True  True  True    True
# 3     True  True  True    True
# 4     True  True  True    True
# ..     ...   ...   ...     ...
# 298   True  True  True    True
# 299   True  True  True    True
# 300   True  True  True    True
# 301   True  True  True    True
# 302   True  True  True    True
#
# [303 rows x 14 columns]

# %%
pd.notnull(df).all()
# Out:
# age         True
# sex         True
# cp          True
# trestbps    True
# chol        True
# fbs         True
# restecg     True
# thalach     True
# exang       True
# oldpeak     True
# slope       True
# ca          True
# thal        True
# target      True
# dtype: bool

# %%
pd.notnull(df).all().all()
# Out:
# True

# %%
assert pd.notnull(df).all().all()

# %%
assert (df>=0).all().all()

# %% [markdown]
# # 12.Outlier Detection
#
# -I will make boxplots to visualise outliers in the continuous numerical variables : -
#
# age, trestbps, chol, thalach and oldpeak variables.

# %%
df['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
#f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=df.age)
plt.grid(axis='x')

# %%
df.trestbps.describe()
# Out:
# count    303.000000
# mean     131.623762
# std       17.538143
# min       94.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: trestbps, dtype: float64

# %%
sns.boxplot(x=df.trestbps)
plt.grid(axis='x')

# %%
df.chol.describe()
# Out:
# count    303.000000
# mean     246.264026
# std       51.830751
# min      126.000000
# 25%      211.000000
# 50%      240.000000
# 75%      274.500000
# max      564.000000
# Name: chol, dtype: float64

# %%
sns.boxplot(x=df.chol)
plt.grid(axis='x')

# %%
df.thalach.describe()
# Out:
# count    303.000000
# mean     149.646865
# std       22.905161
# min       71.000000
# 25%      133.500000
# 50%      153.000000
# 75%      166.000000
# max      202.000000
# Name: thalach, dtype: float64

# %%
sns.boxplot(x=df.thalach)
plt.grid(axis='x')

# %%
df.oldpeak.describe()
# Out:
# count    303.000000
# mean       1.039604
# std        1.161075
# min        0.000000
# 25%        0.000000
# 50%        0.800000
# 75%        1.600000
# max        6.200000
# Name: oldpeak, dtype: float64

# %%
sns.boxplot(x=df.oldpeak)
plt.grid(axis='x')

# %% [markdown]
# # Findings
# The age variable does not contain any outlier.
#
# trestbps variable contains outliers to the right side.
#
# chol variable also contains outliers to the right side.
#
# thalach variable contains a single outlier to the left side.
#
# oldpeak variable contains outliers to the right side.
#
# Those variables containing outliers needs further investigation.

# %% [markdown]
# # End our EDA journey
